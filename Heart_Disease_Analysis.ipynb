# %% [markdown]
# # 1. Import the Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# # 2. Dataset.

# %%
data = pd.read_csv("Heart_Disease_Dataset.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # 3. Show Top 5 Rows of the Dataset.

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # 4. Show Below 5 Rows of the Dataset.

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # 5. Find Shape of our Dataset (No. of Rows and Columns).

# %%
data.shape
# Out:
# (1025, 14)

# %%
print("No. of Rows: ",data.shape[0])
print("No. of Column: ",data.shape[1])
# Out:
# No. of Rows:  1025
# No. of Column:  14

# %% [markdown]
# # 6. Show Column Name of our Dataset.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 7. Information of Dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 8. Check Null Values in the Dataset.

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.loc[350:368] #Location for Dataset.
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 353   57    1   0       110   201    0        1      126      1      1.5
# 355   46    0   0       138   243    0        0      152      1      0.0
# 356   59    1   0       164   176    1        0       90      0      1.0
# 358   59    1   3       134   204    0        1      162      0      0.8
# 361   62    1   2       130   231    0        1      146      0      1.8
# 363   53    1   2       130   246    1        0      173      0      0.0
# 366   58    1   2       112   230    0        0      165      0      2.5
# 367   48    1   1       110   229    0        1      168      0      1.0
# 368   58    1   2       105   240    0        0      154      1      0.6
#
#      slope  ca  thal  target
# 353      1   0     1       1
# 355      1   0     2       1
# 356      1   2     1       0
# 358      2   2     2       0
# 361      1   3     3       1
# 363      2   3     2       1
# ...

# %% [markdown]
# # Sorting.

# %%
data.sort_values('age')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 143   34    1   3       118   182    0        0      174      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# 256   35    0   0       138   183    0        1      182      0      1.4
# 281   35    1   1       122   192    0        1      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 269   71    0   2       110   265    1        0      130      0      0.0
# 287   71    0   1       160   302    0        1      162      0      0.4
# 313   74    0   1       120   269    0        0      121      1      0.2
# 99    76    0   2       140   197    0        2      116      0      1.1
# 160   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 60       2   0     2       1
# 143      2   0     2       1
# ...

# %%
data.sort_values('age',ascending=False)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 160   77    1   0       125   304    0        0      162      1      0.0
# 99    76    0   2       140   197    0        2      116      0      1.1
# 313   74    0   1       120   269    0        0      121      1      0.2
# 269   71    0   2       110   265    1        0      130      0      0.0
# 287   71    0   1       160   302    0        1      162      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 384   35    1   0       126   282    0        0      156      1      0.0
# 281   35    1   1       122   192    0        1      174      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# 143   34    1   3       118   182    0        0      174      0      0.0
# 60    29    1   1       130   204    0        0      202      0      0.0
#
#      slope  ca  thal  target
# 160      2   3     2       0
# 99       1   0     2       1
# ...

# %%
data.groupby('age')['sex'].sum()
# Out:
# age
# 29     1
# 34     1
# 35     3
# 37     1
# 38     2
# 39     2
# 40     3
# 41     6
# 42     6
# 43     6
# 44     9
# 45     5
# 46     4
# 47     5
# 48     6
# 49     3
# 50     4
# 51     8
# 52    12
# 53     5
# 54    11
# 55     4
# 56     8
# 57    13
# 58    13
# 59    13
# 60     7
# 61     6
# 62     4
# 63     4
# 64     7
# 65     4
# 66     4
# 67     6
# 68     3
# 69     2
# 70     4
# 71     0
# 74     0
# 76     0
# 77     1
# Name: sex, dtype: int64

# %%
data.groupby('age')['chol'].sum()
# Out:
# age
# 29     204
# 34     392
# 35     855
# 37     465
# 38     406
# 39     959
# 40     589
# 41    2207
# 42    1974
# 43    2054
# 44    2435
# 45    1979
# 46    1612
# 47    1232
# 48    1756
# 49    1143
# 50    1589
# 51    3104
# 52    2967
# 53    1868
# 54    4053
# 55    2245
# 56    2853
# 57    4055
# 58    4836
# 59    3358
# 60    2701
# 61    1950
# 62    2823
# 63    2324
# 64    2744
# 65    2232
# 66    1720
# 67    2581
# 68     955
# 69     727
# 70    1010
# 71     716
# 74     269
# 76     197
# 77     304
# Name: chol, dtype: int64

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
d=data.groupby('sex')['target'].sum()

# %%
data.groupby('sex')['trestbps'].sum()
# Out:
# sex
# 0    12776
# 1    26968
# Name: trestbps, dtype: int64

# %%
data.groupby('age')['chol'].max()
# Out:
# age
# 29    204
# 34    210
# 35    282
# 37    250
# 38    231
# 39    321
# 40    223
# 41    306
# 42    315
# 43    341
# 44    290
# 45    309
# 46    311
# 47    275
# 48    275
# 49    271
# 50    254
# 51    308
# 52    325
# 53    282
# 54    309
# 55    353
# 56    409
# 57    354
# 58    340
# 59    326
# 60    318
# 61    330
# 62    394
# 63    407
# 64    335
# 65    417
# 66    302
# 67    564
# 68    277
# 69    254
# 70    322
# 71    302
# 74    269
# 76    197
# 77    304
# Name: chol, dtype: int64

# %%
data[data['age']==43]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 11    43    0   0       132   341    1        0      136      1      3.0
# 100   43    0   2       122   213    0        1      165      0      0.2
# 117   43    1   0       120   177    0        0      120      1      2.5
# 168   43    1   2       130   315    0        1      162      0      1.9
# 170   43    1   0       150   247    0        1      171      0      1.5
# 270   43    1   0       110   211    0        1      161      0      0.0
# 348   43    1   0       132   247    1        0      143      1      0.1
# 616   43    1   0       115   303    0        1      181      0      1.2
#
#      slope  ca  thal  target
# 11       1   0     3       0
# 100      1   0     2       1
# 117      1   0     3       0
# 168      2   1     2       1
# 170      2   0     2       1
# 270      2   0     3       1
# 348      1   4     3       0
# 616      1   0     2       1

# %% [markdown]
# # 9. Check Duplicate Value in the Dataset.

# %%
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# True

# %% [markdown]
# # 10. Drop Duplicate Value in the Dataset.

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # 11. Get overall Statics About the Dataset.

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # 12. Show the Correlation Matrix.

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# # 13. How Many Peoples Have Heart Disease, And How Many Don't Have Heart Disease in this Dataset.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # 14. Find Count of Male and Female in this Dataset.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
data['sex'].count()
# Out:
# 302

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts([1])
# Out:
# 1    0.682119
# 0    0.317881
# Name: sex, dtype: float64

# %% [markdown]
# # 15. Find the Gender Distribution According to The Target Value.

# %%
sns.countplot(x="sex", hue="target", data=data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# # 16. Show Age Distribution in this Dataset.

# %%
data2=sns.displot(data['age'], bins=20)
plt.show()

# %% [markdown]
# # 17. Analyse on Chest Pain Type.
# .Chest Pain Type Values(4 values)
#  1. Value 0 = typical angina.
#  2. Value 1 = atypical angina.
#  3. Value 2 = non-anginal pain.
#  4. Value 3 = asymptomatic.

# %%
import seaborn as sns

# %%
sns.displot(data['cp'])
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # 18. Display The Chest Pain Type Distribution As Per Target Value.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x="cp", hue="target", data=data)
plt.legend(labels=["No-Disease","Disease"]  )
plt.show()

# %% [markdown]
# # 19. Display Fasting Blood Sugar Distribution According To Target Value.

# %%
sns.countplot(x="fbs", hue="target", data=data)
plt.legend(labels=["No-Disease","Disease"]  )
plt.show()

# %% [markdown]
# # 20. Expect Resting Blood Presure Distribution.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data["trestbps"].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 21. Compare Between Resting Blood Pressure & Sex Column.

# %%
a = sns.FacetGrid(data,hue="sex", aspect=4)
a.map(sns.kdeplot,'trestbps', fill=True)
plt.legend(labels=["Male","Female"])

# %% [markdown]
# # 22. Display Distribution of Serum Cholesterol.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data["chol"].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
#  # 23. Plot Continuous Variables.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
cate_val=[]
cont_val =[]
for column in data.columns:
    if data[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
data.hist(cont_val,figsize=(12,12))
plt.tight_layout()
plt.show()

# %%
data.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
data.plot.scatter(x='age',y='chol')
# Out:
# <AxesSubplot: xlabel='age', ylabel='chol'>

# %%
data.plot.box()
# Out:
# <AxesSubplot: >

# %%
data.boxplot()
# Out:
# <AxesSubplot: >

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
plt.bar('age',height='chol',data=data)
plt.show()

# %%
data=C

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
data.sort_values('age',ascending=False,inplace=True)

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0      160   77    1   0       125   304    0        0      162      1
# 1       99   76    0   2       140   197    0        2      116      0
# 2      313   74    0   1       120   269    0        0      121      1
# 3      269   71    0   2       110   265    1        0      130      0
# 4      287   71    0   1       160   302    0        1      162      0
# ..     ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 297    384   35    1   0       126   282    0        0      156      1
# 298    281   35    1   1       122   192    0        1      174      0
# 299     12   34    0   1       118   210    0        1      192      0
# 300    143   34    1   3       118   182    0        0      174      0
# 301     60   29    1   1       130   204    0        0      202      0
#
#      oldpeak  slope  ca  thal  target
# 0        0.0      2   3     2       0
# ...

# %%
abc = data.loc[0:10]

# %%
abc
# Out:
#     index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     160   77    1   0       125   304    0        0      162      1
# 1      99   76    0   2       140   197    0        2      116      0
# 2     313   74    0   1       120   269    0        0      121      1
# 3     269   71    0   2       110   265    1        0      130      0
# 4     287   71    0   1       160   302    0        1      162      0
# 5      10   71    0   0       112   149    0        1      125      0
# 6     402   70    1   1       156   245    0        0      143      0
# 7     328   70    1   0       130   322    0        0      109      0
# 8      33   70    1   2       160   269    0        1      112      1
# 9       2   70    1   0       145   174    0        1      125      1
# 10    460   69    1   2       140   254    0        0      146      0
#
#     oldpeak  slope  ca  thal  target
# 0       0.0      2   3     2       0
# 1       1.1      1   0     2       1
# ...

# %%
plt.bar('target','age', data=abc)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='chol',y='age', data=abc)
plt.xticks(rotation=90)
plt.show()

# %%
plt.pie('ca',labels='chol',data=abc,radius=1,rotatelabels=True)
plt.show()

# %%
b=bd.groupby(['age'])['target'].max()
b
# Out:
# age
# 29    1
# 34    1
# 35    1
# 37    1
# 38    1
# 39    1
# 40    1
# 41    1
# 42    1
# 43    1
# 44    1
# 45    1
# 46    1
# 47    1
# 48    1
# 49    1
# 50    1
# 51    1
# 52    1
# 53    1
# 54    1
# 55    1
# 56    1
# 57    1
# 58    1
# 59    1
# 60    1
# 61    1
# 62    1
# 63    1
# 64    1
# 65    1
# 66    1
# 67    1
# 68    1
# 69    1
# 70    1
# 71    1
# 74    1
# 76    1
# 77    0
# Name: target, dtype: int64

# %%
bd=pd.DataFrame(bd)

# %%
bd
# Out:
#     age  target
# 0    29       1
# 1    34       1
# 2    35       1
# 3    37       1
# 4    38       1
# 5    39       1
# 6    40       1
# 7    41       1
# 8    42       1
# 9    43       1
# 10   44       1
# 11   45       1
# 12   46       1
# 13   47       1
# 14   48       1
# 15   49       1
# 16   50       1
# 17   51       1
# 18   52       1
# 19   53       1
# 20   54       1
# 21   55       1
# 22   56       1
# 23   57       1
# 24   58       1
# 25   59       1
# 26   60       1
# 27   61       1
# 28   62       1
# 29   63       1
# 30   64       1
# 31   65       1
# 32   66       1
# 33   67       1
# 34   68       1
# 35   69       1
# 36   70       1
# 37   71       1
# 38   74       1
# 39   76       1
# 40   77       0

# %%
bd.reset_index(inplace=True)

# %%
plt.plot('age','target',data=bd)
plt.xlabel('age')
plt.ylabel('target')
plt.title('age wise maximum haert disease')
plt.show()

# %%
age=[30,45,50]
target=['0','1','2']
# calculate:
#   10/total value *100=10/150*100=1000/150=6.66
# 20/150*100=2000/150=13.3
plt.pie(age,autopct='%1.1f%%',startangle=90,shadow=True,
        explode=[0,0,0.3],labels=target,counterclock=False,radius=1)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid")
f = pd.read_csv("Heart_Disease_Dataset.csv")
print(f.head())
sns.relplot(x="age", y="chol", data=f);
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
f = pd.read_csv("Heart_Disease_Dataset.csv")
print(f.head())
sns.relplot(x="age", y="chol", hue="thalach", data=f);
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
